# %%
#### Fundamentos de Python

# %% [markdown]
# ## Fundamentos de Python

# %%
print('hello world')
# Out:
# hello world

# %%
# variables
__name__ = "josefino"
Name = "josefino"
first_name = "josefino"

fn = "josefino"

# first-name = "josefino"

# anomalias malas practicas
First_name = "josefino"
FirstName = "josefino"
First_Name = "josefino"
# los puntos no funcionan para esta clase de cosas
# first.name = "josefino"

# revisar el pep 8: guia de estilo

# %%
# python commo calculadora
# int: entero
# float: decimales
# str: cadenas de caracteres

edad = 12
peso = 21
altura = 1.78

print( type( altura ) )
print( type( peso ) )
print( type( first_name ) )
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
# formatos en print

edad = 12
peso = 21.56
altura = 1.78

print( "el tipo de dato de altura es", type( altura ) )
print( "el tipo de dato de peso es", type( peso ) )
print( "el tipo de dato de first_name es", type( first_name ) )
# Out:
# el tipo de dato de altura es <class 'float'>
# el tipo de dato de peso es <class 'float'>
# el tipo de dato de first_name es <class 'str'>

# %%
edad = float(edad)
print( "edad", type(edad) )

altura = float(altura)
print( "altura", type(altura) )
# Out:
# edad <class 'float'>
# altura <class 'float'>

# %% [markdown]
# # Ciclos finitos
